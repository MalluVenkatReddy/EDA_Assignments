# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %% [raw]
# #### key features of the wine quality data set:
# ### Input variables (based on physicochemical tests):
#
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
#
# ### Output variable (based on sensory data):
#
# 12 - quality (score between 0 and 10)

# %%
from IPython import display
display.Image("Q1_Mar24.png")

# %% [raw]
# Alchohol, citric acid, sulphates increase the quality of wine and volatile acidity decraese teh quality of wine

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %% [raw]
# There are two ways to handle missing values-
#
# 1. Dropping Missing Values
# 2. Imputing Missing Values With Some Other Value (Preferred)

# %% [raw]
# 1. Dropping Missing Values
# if missing values is of type Missing At Random(MAR) or Missing Completly At Random(MCAR) then it can be deleted.
# One of the biggest disadvantage of dropping missing values is one might end up deleting some useful data as well with missing values.
# There are two ways to remove missing values
#
# Deleting the entire row containing missing values
# Deleting the entire column containing missing values

# %% [raw]
# 2. Imputing Missing Values
# METHOD 1 → Mean Value Imputation
# In this technique we replace missing values with the mean value of the column containing missing values
# Mean Imputation is a great choice, if distribution is normal or close to normal.
#
# In case of skewed distribution we shoud go with meadian value.
#
# METHOD 2: Median Value Imputation
# In this technique we replace all the missing value with median value of the column
#
# METHOD 3: Mode Imputation (Frequent Category Imputation)
# Mode value imputation is mostly used for categorical data. it can also be used for numerical variables as well.
#
# In this technique we replace all the missing values with the most frequent value of the column.

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %% [raw]
# Factors that affect students performance:
#
# gender : sex of students -> (Male/female)
# race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
# parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
# lunch : having lunch before test (standard or free/reduced)
# test preparation course : complete or not complete before test

# %% [raw]
# 1. By using histplot with hue as lunch, we come to know that standard lunch eating students perform well in exams.
# 2. By using histplot with hue as test preperation course completed, we come to know that test preperation course not completed students didn't perform well in exams.

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %% [raw]
# Feature engineering is the process of selecting, transforming, extracting, combining, and manipulating raw data to generate the desired variables for analysis or predictive modeling

# %% [raw]
# the data is straight forward and no need to transform the variables for our model

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
import pandas as pd
import scipy.stats as stat
import pylab
df=pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(df[feature],kde='True')
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)
#    stat.probplot(df[feature],dist='norm')

# %%
for i in df.columns:
    plot_data(df,i)

# %% [raw]
# Based on above pictures, non-normality features are:
# ['citric acid', 'residual sugar','chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'alcohol']

# %%
data=['citric acid', 'residual sugar','chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'alcohol']
fig, axs = plt.subplots(2, 3)
axs[0, 0].boxplot(df['citric acid'])
axs[0, 1].boxplot(df['residual sugar'])
axs[0, 2].boxplot(df['chlorides'])
axs[1, 0].boxplot(df['free sulfur dioxide'])
axs[1, 1].boxplot(df['total sulfur dioxide'])
axs[1, 2].boxplot(df['alcohol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff4ac69e3e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff4ac69d540>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff4ac69f640>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff4ac69e710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff4ac69d4b0>],
#  'means': []}

# %% [raw]
# By removing outliers, we can improve normality

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?
